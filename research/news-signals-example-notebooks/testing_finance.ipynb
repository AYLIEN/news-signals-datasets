# %%
# %load_ext autoreload
# %autoreload 2
import yfinance
from news_signals.yfinance_timeseries import retrieve_yfinance_timeseries

tickers = "AAPL"
start_date = "2024-01-01"
end_date = "2025-01-01"

df = retrieve_yfinance_timeseries(tickers, start_date, end_date, True)
# Out:
# [*********************100%***********************]  1 of 1 completed
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = retrieve_yfinance_timeseries(tickers, start_date)
print(df)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2024-01-02  184.734985  187.521338  182.993517  186.237618   82488700
# 2024-01-03  183.351761  184.973819  182.535751  183.321908   58414500
# 2024-01-04  181.023178  182.197418  179.998201  181.261998   71983600
# 2024-01-05  180.296707  181.869006  179.291637  181.102771   62303300
# 2024-01-08  184.655365  184.695178  180.615161  181.202281   59144500
# ...                ...         ...         ...         ...        ...
# 2025-01-31  236.000000  247.190002  233.440002  247.190002  101075100
# 2025-02-03  228.009995  231.830002  225.699997  229.990005   73063300
# 2025-02-04  232.800003  233.130005  226.649994  227.250000   45067300
# 2025-02-05  232.470001  232.669998  228.270004  228.529999   39620300
# ...

# %%
df = retrieve_yfinance_timeseries("TSLA", start_date, end_date, True)
print(df)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume  \
# Ticker            TSLA        TSLA        TSLA        TSLA       TSLA
# Date
# 2024-01-02  248.419998  251.250000  244.410004  250.080002  104654200
# 2024-01-03  238.449997  245.679993  236.320007  244.979996  121082600
# 2024-01-04  237.929993  242.699997  237.729996  239.250000  102629300
# 2024-01-05  237.490005  240.119995  234.899994  236.860001   92379400
# 2024-01-08  240.449997  241.250000  235.300003  236.139999   85166600
# ...                ...         ...         ...         ...        ...
# 2024-12-24  462.279999  462.779999  435.140015  435.899994   59551800
# 2024-12-26  454.130005  465.329987  451.019989  465.160004   76366400
# 2024-12-27  431.660004  450.000000  426.500000  449.519989   82666800
# 2024-12-30  417.410004  427.000000  415.750000  419.399994   64941000
# ...

# %%
df = retrieve_yfinance_timeseries(["AAPL", "MSFT", "GOOGL"], "2024-01-01", "2025-01-01", plot_rsi=True)
# Out:
# [*********************100%***********************]  3 of 3 completed
